# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request as req
from PIL import Image
import os

# %%
raw = pd.read_json("./data/mtg/AllSets-x.json")

# %%
raw.head()
# Out:
#                                                        10E  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               black
# cards    [{'text': 'First strike (This creature deals c...
# code                                                   10E
#
#                                                        2ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Flying', 'multiverseid': 691, 'prin...
# code                                                   2ED
#
#                                                        3ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Flying', 'multiverseid': 1189, 'pri...
# code                                                   3ED
#
#                                                        4ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Whenever Abomination blocks or beco...
# code                                                   4ED
#
#                                                        5DN  \
# block                                             Mirrodin
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               black
# cards    [{'text': 'Choose one —
# • You gain 5 life.
# • P...
# code                                                   5DN
#
#                                                        5ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Flying, protection from red', 'mult...
# code                                                   5ED
#
#                                                        6ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Enchant Wall
# Enchanted Wall can att...
# code                                                   6ED
#
#                                                        7ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Flying
# {T}: Target attacking or blo...
# code                                                   7ED
#
#                                                        8ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Flying
# When Angel of Mercy enters t...
# code                                                   8ED
#
#                                                        9ED  \
# block                                                  NaN
# booster  [rare, uncommon, uncommon, uncommon, common, c...
# border                                               white
# cards    [{'text': 'Flying
# When Angel of Mercy enters t...
# code                                                   9ED
#
#                                ...                          \
# block                          ...
# booster                        ...
# border                         ...
# cards                          ...
# code                           ...
#
#                                                       pPOD  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'Flying', 'printings': ['POR', 'pPOD...
# code                                                  pPOD
#
#                                                       pPRE  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'Whenever an opponent plays a land, ...
# code                                                  pPRE
#
#                                                       pPRO  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'Flying
# {3}{W}{W}: Return Eternal Dr...
# code                                                  pPRO
#
#                                                       pREL  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'When Rukh Egg dies, put a 4/4 red B...
# code                                                  pREL
#
#                                                       pSUM  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'Faerie Conclave enters the battlefi...
# code                                                  pSUM
#
#                                                       pSUS  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'At the beginning of the end step, i...
# code                                                  pSUS
#
#                                                       pWCQ  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'Haste
# Whenever you cast a spell, if...
# code                                                  pWCQ
#
#                                                       pWOR  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'When Balduvian Horde enters the bat...
# code                                                  pWOR
#
#                                                       pWOS  \
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'Flying (This creature can't be bloc...
# code                                                  pWOS
#
#                                                       pWPN
# block                                                  NaN
# booster                                                NaN
# border                                               black
# cards    [{'text': 'When Sprouting Thrinax dies, put th...
# code                                                  pWPN
#
# [5 rows x 199 columns]

# %%
keeps = ['name', 'colorIdentity', 'colors', 'type', 'types', 'subtypes', 'supertypes', 'cmc', 'power', 'toughness', 'flavor', 'text', 'legalities', 'multiverseid']

# %%
mtg = []
for col in raw.columns.values:
    cards = pd.DataFrame(raw[col]['cards'])
    cards = cards.loc[:,keeps]
    cards['setname'] = col
    mtg.append(cards)

# %%
del cards, raw

# %%
mtg = pd.concat(mtg)

# %%
mtg.shape
# Out:
# (31705, 15)

# %%
mtg.head()
# Out:
#                 name colorIdentity   colors                     type  \
# 0  Ancestor's Chosen           [W]  [White]  Creature — Human Cleric
# 1     Angel of Mercy           [W]  [White]         Creature — Angel
# 2   Angelic Blessing           [W]  [White]                  Sorcery
# 3     Angelic Chorus           [W]  [White]              Enchantment
# 4       Angelic Wall           [W]  [White]          Creature — Wall
#
#            types         subtypes supertypes  cmc power toughness  \
# 0     [Creature]  [Human, Cleric]        NaN  7.0     4         4
# 1     [Creature]          [Angel]        NaN  5.0     3         3
# 2      [Sorcery]              NaN        NaN  3.0   NaN       NaN
# 3  [Enchantment]              NaN        NaN  5.0   NaN       NaN
# 4     [Creature]           [Wall]        NaN  2.0     0         4
#
#                                               flavor  \
# 0                "The will of all, by my hand done."
# 1          Every tear shed is a drop of immortality.
# 2  Only the warrior who can admit mortal weakness...
# 3  The harmony of the glorious is a dirge to the ...
# 4  "The Ancestor protects us in ways we can't beg...
#
#                                                 text  \
# 0  First strike (This creature deals combat damag...
# 1  Flying\nWhen Angel of Mercy enters the battlef...
# 2  Target creature gets +3/+3 and gains flying un...
# 3  Whenever a creature enters the battlefield und...
# 4     Defender (This creature can't attack.)\nFlying
#
#                                           legalities  multiverseid setname
# 0  [{'legality': 'Legal', 'format': 'Commander'},...      130550.0     10E
# 1  [{'legality': 'Legal', 'format': 'Commander'},...      129465.0     10E
# 2  [{'legality': 'Legal', 'format': 'Commander'},...      129711.0     10E
# 3  [{'legality': 'Legal', 'format': 'Commander'},...      129710.0     10E
# 4  [{'legality': 'Legal', 'format': 'Commander'},...      129671.0     10E

# %%
mtg.dtypes
# Out:
# name              object
# colorIdentity     object
# colors            object
# type              object
# types             object
# subtypes          object
# supertypes        object
# cmc              float64
# power             object
# toughness         object
# flavor            object
# text              object
# legalities        object
# multiverseid     float64
# setname           object
# dtype: object

# %%
# take only the ones with images
mtg = mtg.loc[lambda mtg: ~mtg.multiverseid.isnull()]
mtg.shape
# Out:
# (29487, 15)

# %%
mtg['multiverseid'] = mtg['multiverseid'].astype(int).astype(str)

# %%
def download_image_with_id(image_id, replace=False):
    fileName = "./data/mtg/images/" + image_id + ".jpg"
    exists = os.path.exists(fileName)
    if replace or not exists:
        print("Downloading image... " + fileName)
        req.urlretrieve("http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=" + image_id + "&type=card", fileName)
    print("Done downloading...")

# %%
# Download Images
for image_id in mtg.iloc[100:500].multiverseid:
    download_image_with_id(image_id)
# Out:
# Downloading image... ./data/mtg/images/134764.jpg
# Downloading image... ./data/mtg/images/129733.jpg
# Downloading image... ./data/mtg/images/135252.jpg
# Downloading image... ./data/mtg/images/135217.jpg
# Downloading image... ./data/mtg/images/130818.jpg
# Downloading image... ./data/mtg/images/129719.jpg
# Downloading image... ./data/mtg/images/129553.jpg
# Downloading image... ./data/mtg/images/136217.jpg
# Downloading image... ./data/mtg/images/130998.jpg
# Downloading image... ./data/mtg/images/129471.jpg
# Downloading image... ./data/mtg/images/129901.jpg
# Downloading image... ./data/mtg/images/129509.jpg
# Downloading image... ./data/mtg/images/129761.jpg
# Downloading image... ./data/mtg/images/132071.jpg
# Downloading image... ./data/mtg/images/129764.jpg
# Downloading image... ./data/mtg/images/129770.jpg
# Downloading image... ./data/mtg/images/129898.jpg
# Downloading image... ./data/mtg/images/129677.jpg
# Downloading image... ./data/mtg/images/129774.jpg
# Downloading image... ./data/mtg/images/129887.jpg
# Downloading image... ./data/mtg/images/136286.jpg
# Downloading image... ./data/mtg/images/136218.jpg
# Downloading image... ./data/mtg/images/130834.jpg
# Downloading image... ./data/mtg/images/135274.jpg
# Downloading image... ./data/mtg/images/135206.jpg
# Downloading image... ./data/mtg/images/135228.jpg
# Downloading image... ./data/mtg/images/106525.jpg
# Downloading image... ./data/mtg/images/135194.jpg
# Downloading image... ./data/mtg/images/135270.jpg
# Downloading image... ./data/mtg/images/129491.jpg
# Downloading image... ./data/mtg/images/129505.jpg
# Downloading image... ./data/mtg/images/129590.jpg
# Downloading image... ./data/mtg/images/129514.jpg
# Downloading image... ./data/mtg/images/129910.jpg
# Downloading image... ./data/mtg/images/129525.jpg
# Downloading image... ./data/mtg/images/135219.jpg
# Downloading image... ./data/mtg/images/129880.jpg
# Downloading image... ./data/mtg/images/135216.jpg
# Downloading image... ./data/mtg/images/129529.jpg
# Downloading image... ./data/mtg/images/129490.jpg
# Downloading image... ./data/mtg/images/135191.jpg
# Downloading image... ./data/mtg/images/129544.jpg
# Downloading image... ./data/mtg/images/129546.jpg
# Downloading image... ./data/mtg/images/129583.jpg
# Downloading image... ./data/mtg/images/135256.jpg
# Downloading image... ./data/mtg/images/129584.jpg
# Downloading image... ./data/mtg/images/130995.jpg
# Downloading image... ./data/mtg/images/135255.jpg
# Downloading image... ./data/mtg/images/135234.jpg
# Downloading image... ./data/mtg/images/129564.jpg
# Downloading image... ./data/mtg/images/129600.jpg
# Downloading image... ./data/mtg/images/129574.jpg
# Downloading image... ./data/mtg/images/129628.jpg
# Downloading image... ./data/mtg/images/135271.jpg
# Downloading image... ./data/mtg/images/129629.jpg
# Downloading image... ./data/mtg/images/135218.jpg
# Downloading image... ./data/mtg/images/129640.jpg
# Downloading image... ./data/mtg/images/135272.jpg
# Downloading image... ./data/mtg/images/129645.jpg
# Downloading image... ./data/mtg/images/135259.jpg
# Downloading image... ./data/mtg/images/129648.jpg
# Downloading image... ./data/mtg/images/129653.jpg
# Downloading image... ./data/mtg/images/129658.jpg
# Downloading image... ./data/mtg/images/129659.jpg
# Downloading image... ./data/mtg/images/136283.jpg
# Downloading image... ./data/mtg/images/106427.jpg
# Downloading image... ./data/mtg/images/135189.jpg
# Downloading image... ./data/mtg/images/129678.jpg
# Downloading image... ./data/mtg/images/129679.jpg
# Downloading image... ./data/mtg/images/135220.jpg
# Downloading image... ./data/mtg/images/129692.jpg
# Downloading image... ./data/mtg/images/135188.jpg
# Downloading image... ./data/mtg/images/135236.jpg
# Downloading image... ./data/mtg/images/129708.jpg
# Downloading image... ./data/mtg/images/129718.jpg
# Downloading image... ./data/mtg/images/129724.jpg
# Downloading image... ./data/mtg/images/129693.jpg
# Downloading image... ./data/mtg/images/129803.jpg
# Downloading image... ./data/mtg/images/129739.jpg
# Downloading image... ./data/mtg/images/129743.jpg
# Downloading image... ./data/mtg/images/135197.jpg
# Downloading image... ./data/mtg/images/135199.jpg
# Downloading image... ./data/mtg/images/136282.jpg
# Downloading image... ./data/mtg/images/129779.jpg
# Downloading image... ./data/mtg/images/129780.jpg
# Downloading image... ./data/mtg/images/135195.jpg
# Downloading image... ./data/mtg/images/134753.jpg
# Downloading image... ./data/mtg/images/130530.jpg
# Downloading image... ./data/mtg/images/135262.jpg
# Downloading image... ./data/mtg/images/129484.jpg
# Downloading image... ./data/mtg/images/129709.jpg
# Downloading image... ./data/mtg/images/130384.jpg
# Downloading image... ./data/mtg/images/130534.jpg
# Downloading image... ./data/mtg/images/130535.jpg
# Downloading image... ./data/mtg/images/129909.jpg
# Downloading image... ./data/mtg/images/129522.jpg
# Downloading image... ./data/mtg/images/143024.jpg
# Downloading image... ./data/mtg/images/129579.jpg
# Downloading image... ./data/mtg/images/129554.jpg
# Downloading image... ./data/mtg/images/129548.jpg
# Downloading image... ./data/mtg/images/130379.jpg
# Downloading image... ./data/mtg/images/130378.jpg
# Downloading image... ./data/mtg/images/130542.jpg
# Downloading image... ./data/mtg/images/129566.jpg
# Downloading image... ./data/mtg/images/130386.jpg
# Downloading image... ./data/mtg/images/130380.jpg
# Downloading image... ./data/mtg/images/129578.jpg
# Downloading image... ./data/mtg/images/135221.jpg
# Downloading image... ./data/mtg/images/129580.jpg
# Downloading image... ./data/mtg/images/129582.jpg
# Downloading image... ./data/mtg/images/129588.jpg
# Downloading image... ./data/mtg/images/129591.jpg
# Downloading image... ./data/mtg/images/134751.jpg
# Downloading image... ./data/mtg/images/106398.jpg
# Downloading image... ./data/mtg/images/129620.jpg
# Downloading image... ./data/mtg/images/130373.jpg
# Downloading image... ./data/mtg/images/129624.jpg
# Downloading image... ./data/mtg/images/130367.jpg
# Downloading image... ./data/mtg/images/134748.jpg
# Downloading image... ./data/mtg/images/129663.jpg
# Downloading image... ./data/mtg/images/134752.jpg
# Downloading image... ./data/mtg/images/129801.jpg
# Downloading image... ./data/mtg/images/130997.jpg
# Downloading image... ./data/mtg/images/129688.jpg
# Downloading image... ./data/mtg/images/129697.jpg
# Downloading image... ./data/mtg/images/129715.jpg
# Downloading image... ./data/mtg/images/130374.jpg
# Downloading image... ./data/mtg/images/129884.jpg
# Downloading image... ./data/mtg/images/130370.jpg
# Downloading image... ./data/mtg/images/129730.jpg
# Downloading image... ./data/mtg/images/130538.jpg
# Downloading image... ./data/mtg/images/129732.jpg
# Downloading image... ./data/mtg/images/130362.jpg
# Downloading image... ./data/mtg/images/130539.jpg
# Downloading image... ./data/mtg/images/130532.jpg
# Downloading image... ./data/mtg/images/130369.jpg
# Downloading image... ./data/mtg/images/129577.jpg
# Downloading image... ./data/mtg/images/136509.jpg
# Downloading image... ./data/mtg/images/106473.jpg
# Downloading image... ./data/mtg/images/134755.jpg
# Downloading image... ./data/mtg/images/129750.jpg
# Downloading image... ./data/mtg/images/129767.jpg
# Downloading image... ./data/mtg/images/130381.jpg
# Downloading image... ./data/mtg/images/134756.jpg
# Downloading image... ./data/mtg/images/130531.jpg
# Downloading image... ./data/mtg/images/130387.jpg
# Downloading image... ./data/mtg/images/136284.jpg
# Downloading image... ./data/mtg/images/130364.jpg
# Downloading image... ./data/mtg/images/130483.jpg
# Downloading image... ./data/mtg/images/130525.jpg
# Downloading image... ./data/mtg/images/135249.jpg
# Downloading image... ./data/mtg/images/129906.jpg
# Downloading image... ./data/mtg/images/135267.jpg
# Downloading image... ./data/mtg/images/135185.jpg
# Downloading image... ./data/mtg/images/130522.jpg
# Downloading image... ./data/mtg/images/130521.jpg
# Downloading image... ./data/mtg/images/130527.jpg
# Downloading image... ./data/mtg/images/129512.jpg
# Downloading image... ./data/mtg/images/135266.jpg
# Downloading image... ./data/mtg/images/129533.jpg
# Downloading image... ./data/mtg/images/129534.jpg
# Downloading image... ./data/mtg/images/129535.jpg
# Downloading image... ./data/mtg/images/135263.jpg
# Downloading image... ./data/mtg/images/135186.jpg
# Downloading image... ./data/mtg/images/129789.jpg
# Downloading image... ./data/mtg/images/129568.jpg
# Downloading image... ./data/mtg/images/129570.jpg
# Downloading image... ./data/mtg/images/129586.jpg
# Downloading image... ./data/mtg/images/129599.jpg
# Downloading image... ./data/mtg/images/129885.jpg
# Downloading image... ./data/mtg/images/130500.jpg
# Downloading image... ./data/mtg/images/129911.jpg
# Downloading image... ./data/mtg/images/129511.jpg
# Downloading image... ./data/mtg/images/129626.jpg
# Downloading image... ./data/mtg/images/129536.jpg
# Downloading image... ./data/mtg/images/135226.jpg
# Downloading image... ./data/mtg/images/129642.jpg
# Downloading image... ./data/mtg/images/130996.jpg
# Downloading image... ./data/mtg/images/106405.jpg
# Downloading image... ./data/mtg/images/106368.jpg
# Downloading image... ./data/mtg/images/129655.jpg
# Downloading image... ./data/mtg/images/129656.jpg
# Downloading image... ./data/mtg/images/135282.jpg
# Downloading image... ./data/mtg/images/130506.jpg
# Downloading image... ./data/mtg/images/130526.jpg
# Downloading image... ./data/mtg/images/136288.jpg
# Downloading image... ./data/mtg/images/130489.jpg
# Downloading image... ./data/mtg/images/129690.jpg
# Downloading image... ./data/mtg/images/130507.jpg
# Downloading image... ./data/mtg/images/129696.jpg
# Downloading image... ./data/mtg/images/106504.jpg
# Downloading image... ./data/mtg/images/135251.jpg
# Downloading image... ./data/mtg/images/129707.jpg
# Downloading image... ./data/mtg/images/136285.jpg
# Downloading image... ./data/mtg/images/130504.jpg
# Downloading image... ./data/mtg/images/129722.jpg
# Downloading image... ./data/mtg/images/135182.jpg
# Downloading image... ./data/mtg/images/129742.jpg
# Downloading image... ./data/mtg/images/135184.jpg
# Downloading image... ./data/mtg/images/135264.jpg
# Downloading image... ./data/mtg/images/135215.jpg
# Downloading image... ./data/mtg/images/130513.jpg
# Downloading image... ./data/mtg/images/135231.jpg
# Downloading image... ./data/mtg/images/129777.jpg
# Downloading image... ./data/mtg/images/130498.jpg
# Downloading image... ./data/mtg/images/130494.jpg
# Downloading image... ./data/mtg/images/129788.jpg
# Downloading image... ./data/mtg/images/129792.jpg
# Downloading image... ./data/mtg/images/129773.jpg
# Downloading image... ./data/mtg/images/130515.jpg
# Downloading image... ./data/mtg/images/129466.jpg
# Downloading image... ./data/mtg/images/129495.jpg
# Downloading image... ./data/mtg/images/135254.jpg
# Downloading image... ./data/mtg/images/135279.jpg
# Downloading image... ./data/mtg/images/135244.jpg
# Downloading image... ./data/mtg/images/129502.jpg
# Downloading image... ./data/mtg/images/135268.jpg
# Downloading image... ./data/mtg/images/135275.jpg
# Downloading image... ./data/mtg/images/129480.jpg
# Downloading image... ./data/mtg/images/129523.jpg
# Downloading image... ./data/mtg/images/135243.jpg
# Downloading image... ./data/mtg/images/129527.jpg
# Downloading image... ./data/mtg/images/135273.jpg
# Downloading image... ./data/mtg/images/135253.jpg
# Downloading image... ./data/mtg/images/129598.jpg
# Downloading image... ./data/mtg/images/129601.jpg
# Downloading image... ./data/mtg/images/106478.jpg
# Downloading image... ./data/mtg/images/135240.jpg
# Downloading image... ./data/mtg/images/129619.jpg
# Downloading image... ./data/mtg/images/135242.jpg
# Downloading image... ./data/mtg/images/135277.jpg
# Downloading image... ./data/mtg/images/129630.jpg
# Downloading image... ./data/mtg/images/136289.jpg
# Downloading image... ./data/mtg/images/129643.jpg
# Downloading image... ./data/mtg/images/135280.jpg
# Downloading image... ./data/mtg/images/129665.jpg
# Downloading image... ./data/mtg/images/135281.jpg
# Downloading image... ./data/mtg/images/129526.jpg
# Downloading image... ./data/mtg/images/106537.jpg
# Downloading image... ./data/mtg/images/106552.jpg
# Downloading image... ./data/mtg/images/129704.jpg
# Downloading image... ./data/mtg/images/135241.jpg
# Downloading image... ./data/mtg/images/129741.jpg
# Downloading image... ./data/mtg/images/135235.jpg
# Downloading image... ./data/mtg/images/135278.jpg
# Downloading image... ./data/mtg/images/129809.jpg
# Downloading image... ./data/mtg/images/129458.jpg
# Downloading image... ./data/mtg/images/129479.jpg
# Downloading image... ./data/mtg/images/129496.jpg
# Downloading image... ./data/mtg/images/129497.jpg
# Downloading image... ./data/mtg/images/106531.jpg
# Downloading image... ./data/mtg/images/106428.jpg
# Downloading image... ./data/mtg/images/106564.jpg
# Downloading image... ./data/mtg/images/129614.jpg
# Downloading image... ./data/mtg/images/129627.jpg
